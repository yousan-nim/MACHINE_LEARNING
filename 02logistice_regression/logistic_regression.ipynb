# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# for classification our data

# %%
# LOAD IRIS DATASET
data = datasets.load_iris()

# %%
# EXPORT DATA
# .keys() => export all colummns in datasets
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
# IRIS Discription
print(data.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X = data.data
Y = data.target

# %%
X.shape
# Out:
# (150, 4)

# %%
Y.shape
# Out:
# (150,)

# %%
# SPLIT DATA 
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, random_state=42) # sklearn.model_selection.train_test_split()

# %%
# VISUALISE DATA 

scatter = pd.DataFrame(Xtrain, columns=iris.feature_names)
pd.plotting.scatter_matrix(scatter, c=Ytrain, figsize=(12,12), marker="o")
# Out:
# array([[<AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal length (cm)'>,
#         <AxesSubplot:xlabel='sepal width (cm)', ylabel='sepal length (cm)'>,
#         <AxesSubplot:xlabel='petal length (cm)', ylabel='sepal length (cm)'>,
#         <AxesSubplot:xlabel='petal width (cm)', ylabel='sepal length (cm)'>],
#        [<AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>,
#         <AxesSubplot:xlabel='sepal width (cm)', ylabel='sepal width (cm)'>,
#         <AxesSubplot:xlabel='petal length (cm)', ylabel='sepal width (cm)'>,
#         <AxesSubplot:xlabel='petal width (cm)', ylabel='sepal width (cm)'>],
#        [<AxesSubplot:xlabel='sepal length (cm)', ylabel='petal length (cm)'>,
#         <AxesSubplot:xlabel='sepal width (cm)', ylabel='petal length (cm)'>,
#         <AxesSubplot:xlabel='petal length (cm)', ylabel='petal length (cm)'>,
#         <AxesSubplot:xlabel='petal width (cm)', ylabel='petal length (cm)'>],
# ...

# %%
# LOGISTIC REGRESSION ALGORITHM
'''
Hypothesis || Theory 
    - sigmoid function 
        sigmoid(z) = z / (1 + e^(-z))
    
    - cost function -> cross entropy loss 
        cross_entropy_loss(Y, y) = -ylog(y) - (1-y)log(1-Y)
        
    - gradient descent 
        w = w - lr(dJ(Y, y)/dw0)
        
    - softmax function
        softmax = np.exp(z)/np.sum(np.exp(z))
        
'''

model = LogisticRegression(max_iter=200, random_state=42)
model.fit(Xtrain, Ytrain)
# Out:
# LogisticRegression(max_iter=200, random_state=42)

# %%
# EVALUATE DATASET
print("Train set accuracy = " + str(model.score(Xtrain, Ytrain)))
print("Test set accuracy = " + str(model.score(Xtest, Ytest)))
# Out:
# Train set accuracy = 0.9642857142857143
# Test set accuracy = 1.0

# %%
# INPUT NEW DATA FOR PREDICTION

new_Data = np.array([[8, 3, 5, 2.5]])

predict = model.predict(new_Data)
prob = model.predict_proba(new_Data)

print("Prediction resualt : ", data['target_names'][predict[0]])
print("Probality :",prob[0][0])
# Out:
# Prediction resualt :  virginica
# Probality : 9.829967160723662e-05

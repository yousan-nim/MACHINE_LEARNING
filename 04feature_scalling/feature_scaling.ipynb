# %%
'''
Machine Learning Model will work good when inputs there are Mean = 0 and Variance = 1
That why we need feature scaling before trainning model

    x_scaled = (xi - u) / sigma
    
    variance = (1/m)(sum(xi - u)^2) 

'''
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
import numpy as np

Xtrain = np.random.randint(0, 100, size=(225, 1))
Xtrain = Xtrain.reshape(-1, 1)
Ytrain = np.arange(0, Xtrain.shape[0])
Ytrain = Ytrain.reshape(-1, 1)

Xscaler = preprocessing.StandardScaler().fit(Xtrain)
scaler

Xscaler = preprocessing.StandardScaler().fit(Xtrain)

# %%
# Xtrain

# %%
Xscaled = scale(Xtrain)
Yscaled = scale(Ytrain)

# print(Xscaled)
# print(Yscaled)

# %%
# SCALED DATA HAS ZERO AND UNIT VARIANCE
plt.scatter(Xtrain, Ytrain)

# %%
plt.scatter(Xscaled, Yscaled)

# %%
Xtrain[0]
# Out:
# array([83])

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(Xtrain)
y_scaled = scaler.fit_transform(Ytrain)
print(x_scaled[:5, :])
print(y_scaled[:5, :])
# Out:
# [[ 1.21688265]
#  [-1.50251502]
#  [-0.50425512]
#  [ 0.76938683]
#  [ 1.59553296]]
# [[-1.72436983]
#  [-1.70897368]
#  [-1.69357752]
#  [-1.67818136]
#  [-1.6627852 ]]

# %%
plt.scatter(x_scaled, y_scaled)
